# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('insurance_fraud_data.csv')

print(f"Initial shape: {df.shape}")
df.head()
# Out:
# Initial shape: (12002, 29)
#    claim_number  age_of_driver gender marital_status  safety_rating  \
# 0        414724             39      M              1             73
# 1        269568             33      M              1             72
# 2        974592             31      M              1             76
# 3        995328             53      F              1             93
# 4       1140480             41      M              1             87
#
#    annual_income  high_education  address_change property_status  zip_code  \
# 0        58612.8               1               0             Own     50048
# 1        35936.0               0               1             Own     50006
# 2        84940.8               1               1             Own     15021
# 3        73526.4               0               1             Own     85027
# 4        59403.2               1               0             Own     80046
#
# ...

# %%
# Global Replacement of noise characters
df.replace(['*', '?', 'NA'], np.nan, inplace=True)

# %%
# List of all columns that should be strictly 0 or 1
binary_columns = [
    'marital_status', 
    'high_education', 
    'address_change', 
    'witness_present', 
    'police_report'
]

for col in binary_columns:
    df[col] = pd.to_numeric(df[col], errors='coerce')
    
    col_mode = df[col].mode()[0]
    df[col] = df[col].fillna(col_mode).astype(int)

# %%
# ZIP CODE SPECIAL HANDLING
# we use a placeholder '99999' to represent "Unknown/Missing"
df['zip_code'] = df['zip_code'].replace(0, np.nan)
df['zip_code'] = df['zip_code'].fillna(99999).astype(int)

# %%
#  Standardize text: Remove spaces and make uppercase (M, F)
df['gender'] = df['gender'].str.strip().str.upper()

#  Map to full words for better Dashboard labels
df['gender'] = df['gender'].map({'M': 'Male', 'F': 'Female'})

#  Handle missing values: 
gender_mode = df['gender'].mode()[0]
df['gender'] = df['gender'].fillna(gender_mode)

# %%
df['fraud_reported'] = (
    df['fraud reported']
    .str.strip()          
    .str.upper()          
    .map({'Y': 1, 'N': 0})
)

# Fill unexpected/missing values with the mode (most common)
fraud_mode = df['fraud_reported'].mode()[0]
df['fraud_reported'] = df['fraud_reported'].fillna(fraud_mode).astype(int)

# Drop original column
df = df.drop(columns=['fraud reported'])

# %%
# General Numeric Cleaning & Imputation
numeric_cols = ['annual_income', 'policy deductible', 'annual premium', 
                'liab_prct', 'past_num_of_claims', 'age_of_driver', 
                'total_claim', 'injury_claim', 'vehicle_price']

for col in numeric_cols:
    if df[col].dtype == 'object':
        df[col] = df[col].astype(str).str.replace(r'[$,]', '', regex=True)
    df[col] = pd.to_numeric(df[col], errors='coerce')
    if df[col].isnull().sum() > 0:
        df[col] = df[col].fillna(df[col].median())

# %%
# LOGICAL FIXES & DATES
df['annual_income'] = df['annual_income'].abs()
df['age_of_driver'] = df['age_of_driver'].abs().clip(18, 100)
df['claim_date'] = pd.to_datetime(df['claim_date'], errors='coerce').ffill()
df['claim_year'] = df['claim_date'].dt.year
df['claim_month'] = df['claim_date'].dt.month_name()

# %%
df.describe()
# Out:
#        claim_number  age_of_driver  marital_status  safety_rating  \
# count  1.200200e+04   12002.000000    12002.000000   12002.000000
# mean   3.119801e+08      43.489252        0.715214      73.702966
# min    1.866240e+05      19.000000        0.000000       2.000000
# 25%    1.561887e+08      35.000000        0.000000      66.000000
# 50%    3.121908e+08      43.000000        1.000000      76.000000
# 75%    4.677938e+08      51.000000        1.000000      85.000000
# max    6.220385e+08     100.000000        1.000000     100.000000
# std    1.795997e+08      11.821440        0.451331      15.378967
#
#        annual_income  high_education  address_change      zip_code  \
# count   12002.000000    12002.000000    12002.000000  12002.000000
# mean    63658.228567        0.698134        0.576737  49929.024496
# min         1.000000        0.000000        0.000000  15001.000000
# 25%     56899.200000        0.000000        0.000000  20111.000000
# ...

# %%
df.head()
# Out:
#    claim_number  age_of_driver  gender  marital_status  safety_rating  \
# 0        414724             39    Male               1             73
# 1        269568             33    Male               1             72
# 2        974592             31    Male               1             76
# 3        995328             53  Female               1             93
# 4       1140480             41    Male               1             87
#
#    annual_income  high_education  address_change property_status  zip_code  \
# 0        58612.8               1               0             Own     50048
# 1        35936.0               0               1             Own     50006
# 2        84940.8               1               1             Own     15021
# 3        73526.4               0               1             Own     85027
# 4        59403.2               1               0             Own     80046
#
#    ... vehicle_color  total_claim injury_claim  policy deductible  \
# ...

# %%
df.columns = df.columns.str.replace(' ', '_').str.lower()
df.to_csv('insurance_fraud_data_cleaned.csv', index=False)

# %%
df['fraud_reported'].unique()
df.head()
# Out:
#    claim_number  age_of_driver  gender  marital_status  safety_rating  \
# 0        414724             39    Male               1             73
# 1        269568             33    Male               1             72
# 2        974592             31    Male               1             76
# 3        995328             53  Female               1             93
# 4       1140480             41    Male               1             87
#
#    annual_income  high_education  address_change property_status  zip_code  \
# 0        58612.8               1               0             Own     50048
# 1        35936.0               0               1             Own     50006
# 2        84940.8               1               1             Own     15021
# 3        73526.4               0               1             Own     85027
# 4        59403.2               1               0             Own     80046
#
#    ... vehicle_color  total_claim injury_claim  policy_deductible  \
# ...
